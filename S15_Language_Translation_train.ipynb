# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# %cd /kaggle/working
# !rm -vrf S15
# Out:
# /kaggle/working
# removed 'S15/transformer_model.py'
# removed 'S15/README.md'
# removed 'S15/config.py'
# removed 'S15/S15_Language_Translation_train.ipynb'
# removed 'S15/transformer_litmodule.py'
# removed 'S15/dataset.py'
# removed 'S15/state.db'
# removed 'S15/runs/tmodel/events.out.tfevents.1693599629.9e61733b0703.28.0'
# removed directory 'S15/runs/tmodel'
# removed directory 'S15/runs'
# removed 'S15/tokenizer_en.json'
# removed 'S15/.git/index'
# removed 'S15/.git/config'
# removed 'S15/.git/logs/refs/remotes/origin/HEAD'
# removed directory 'S15/.git/logs/refs/remotes/origin'
# removed directory 'S15/.git/logs/refs/remotes'
# removed 'S15/.git/logs/refs/heads/main'
# removed directory 'S15/.git/logs/refs/heads'
# removed directory 'S15/.git/logs/refs'
# removed 'S15/.git/logs/HEAD'
# removed directory 'S15/.git/logs'
# removed 'S15/.git/refs/remotes/origin/HEAD'
# removed directory 'S15/.git/refs/remotes/origin'
# removed directory 'S15/.git/refs/remotes'
# removed 'S15/.git/refs/heads/main'
# removed directory 'S15/.git/refs/heads'
# removed directory 'S15/.git/refs'
# removed 'S15/.git/description'
# removed 'S15/.git/info/exclude'
# removed directory 'S15/.git/info'
# removed 'S15/.git/HEAD'
# removed 'S15/.git/packed-refs'
# removed 'S15/.git/hooks/pre-merge-commit.sample'
# removed 'S15/.git/hooks/commit-msg.sample'
# removed 'S15/.git/hooks/fsmonitor-watchman.sample'
# removed 'S15/.git/hooks/update.sample'
# removed 'S15/.git/hooks/pre-rebase.sample'
# removed 'S15/.git/hooks/prepare-commit-msg.sample'
# removed 'S15/.git/hooks/push-to-checkout.sample'
# removed 'S15/.git/hooks/pre-push.sample'
# removed 'S15/.git/hooks/pre-applypatch.sample'
# removed 'S15/.git/hooks/pre-receive.sample'
# removed 'S15/.git/hooks/post-update.sample'
# removed 'S15/.git/hooks/pre-commit.sample'
# removed 'S15/.git/hooks/applypatch-msg.sample'
# removed directory 'S15/.git/hooks'
# removed 'S15/.git/objects/pack/pack-c1ecfc66cb03ff861742d0cbce6ab406db3cdf72.pack'
# removed 'S15/.git/objects/pack/pack-c1ecfc66cb03ff861742d0cbce6ab406db3cdf72.idx'
# removed directory 'S15/.git/objects/pack'
# removed directory 'S15/.git/objects'
# removed directory 'S15/.git'
# removed 'S15/__pycache__/transformer_model.cpython-310.pyc'
# removed 'S15/__pycache__/dataset.cpython-310.pyc'
# removed 'S15/__pycache__/config.cpython-310.pyc'
# removed 'S15/__pycache__/transformer_litmodule.cpython-310.pyc'
# removed directory 'S15/__pycache__'
# removed directory 'S15'

# %%
# %cd /kaggle/working
# !git clone https://github.com/mHemaAP/S15.git
# %cd S15
# Out:
# Cloning into 'S15'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 3), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (15/15), 15.18 KiB | 3.04 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /kaggle/working/S15

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 10

# %%
import transformer_litmodule
from pytorch_lightning import LightningModule

lang_trans_model = transformer_litmodule.TransformerLitModule(cfg)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# stty: 'standard input': Inappropriate ioctl for device

# %%
from pytorch_lightning import Trainer

trainer = Trainer(
    accelerator = 'gpu',
    max_epochs = cfg['num_epochs'],
    precision= '16-mixed',
)

# %%
# Fit model
trainer.fit(lang_trans_model)
# Out:
# Downloading builder script:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/7.98k [00:00<?, ?B/s]
# Downloading and preparing dataset opus_books/en-it (download: 3.14 MiB, generated: 8.58 MiB, post-processed: Unknown size, total: 11.72 MiB) to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf...
# Downloading data:   0%|          | 0.00/3.30M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Max length of source sentence: 309
# Max length of target sentence: 274
# Sanity Checking: 0it [00:00, ?it/s]
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:486: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# --------------------------------------------------------------------------------
#     SOURCE: 'Ours is peasant's business; we look after everything ourselves.
#     TARGET: — Ma questo è affar nostro di contadini.
#  PREDICTED: ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente timor timor timor pentola ironicamente pentola ironicamente pentola pentola pentola inviò inviò inviò timor timor pentola pentola pentola inviò inviò inviò grigia timor timor ironicamente grigia inviò inviò inviò inviò inviò inviò inviò inviò inviò timor timor grigia timor timor timor timor grigia grigia annuale annuale timor timor timor timor grigia grigia grigia grigia grigia grigia separammo separammo separammo separammo grigia grigia grigia grigia meramente annuale ironicamente grigia separammo grigia grigia grigia separammo separammo separammo separammo separammo pentola inviò inviò inviò inviò inviò annuale annuale timor timor timor timor timor pentola separammo annuale pentola separammo pentola separammo separammo separammo separammo separammo pentola separammo pentola separammo annuale timor separammo separammo separammo separammo ironicamente ironicamente ironicamente ironicamente separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo sorprendo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo bella bella timor timor separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo annuale separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo annuale separammo annuale separammo annuale annuale annuale separammo separammo separammo separammo separammo annuale separammo annuale timor separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo pentola pentola pentola pentola separammo separammo separammo separammo separammo annuale separammo annuale separammo annuale separammo separammo annuale separammo annuale separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo separammo pentola pentola pentola interrotta annuale annuale annuale annuale
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: 'But perhaps he can't help it,' she said to herself; 'his eyes are so very nearly at the top of his head.
#     TARGET: “Ma forse non può farne a meno, — disse fra sè — ha gli occhi quasi sull'orlo della fronte!
#  PREDICTED: ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente pentola ironicamente ironicamente ironicamente ironicamente ironicamente pentola ironicamente pentola ironicamente studenti studenti studenti studenti studenti studenti studenti studenti ironicamente pentola ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente studenti studenti studenti ironicamente ironicamente ironicamente sorprendo ironicamente sorprendo ironicamente ironicamente timor timor timor timor timor augurava ironicamente timor timor timor timor sorprendo ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente timor timor ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente timor timor Vostro ironicamente ironicamente ironicamente ironicamente ironicamente Vostro Vostro ironicamente ironicamente timor sorprendo ironicamente sorprendo ironicamente sorprendo ironicamente sorprendo ironicamente pentola ironicamente sorprendo ironicamente sorprendo ironicamente sorprendo ironicamente sorprendo ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente sorprendo ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente pelle sorprendo ironicamente sorprendo ironicamente sorprendo ironicamente timor sorprendo ironicamente sorprendo ironicamente timor sorprendo ironicamente timor timor sorprendo ironicamente sorprendo sorprendo sorprendo ironicamente sorprendo ironicamente sorprendo sorprendo sorprendo sorprendo sorprendo ironicamente sorprendo ironicamente timor sorprendo ironicamente sorprendo ironicamente ironicamente pelle Vostro char sorprendo ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente separammo pelle saldezza saldezza saldezza ironicamente ironicamente sorprendo spirando sorprendo saldezza sorprendo ironicamente pelle sorprendo ironicamente sorprendo spirando sorprendo ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente timor timor timor timor timor timor spirando timor spirando timor timor timor timor timor Pava ironicamente ironicamente pentola ironicamente pentola timor Pava Pava Pava Pava Pava pentola pentola pentola pentola pelle sbarcati pelle ironicamente pelle ironicamente pentola char timor Pava pentola timor timor timor timor timor pentola pentola pentola pentola pentola separammo pentola pentola pentola pentola pentola timor Pava Pava Pava Pava Pava Pava Pava pentola ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente timor ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente timor timor timor timor timor ironicamente ironicamente ironicamente ironicamente ironicamente sorprendo ironicamente pentola ironicamente pentola ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente ironicamente Pava Pava Pava pentola timor pentola timor Pava pentola ironicamente pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola pentola timor
# --------------------------------------------------------------------------------
# Val CER at end of epoch 0 = 50.58015441894531
# Val WER at end of epoch 0 = 25.851852416992188
# Val BLEU at end of epoch 0 = 0.0
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: But, not to seem to be making up to Vronsky, he immediately added a slightly condemnatory remark. 'But I am surprised, Count, that you, who are doing so much for the people from a sanitary point of view, should be so indifferent to the schools!'
#     TARGET: Ma poi per non mostrarsi ammiratore incondizionato di Vronskij, aggiunse subito un’osservazione lievemente critica. — Ma mi sorprendo, conte — disse — come voi, che fate tanto per la salute del popolo, siate così indifferente alle scuole.
#  PREDICTED: Ma non si , ma non si , ma non si , ma , ma , ma , ma , ma , e , ma , ma non si , e , e , e , e , e , e .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: And I cannot see the least use that the greatest knowledge of the disputed points of religion, which have made such confusion in the world, would have been to us, if we could have obtained it.
#     TARGET: E da vero non so vedere di qual menomo vantaggio sarebbe stata a noi, quand’anche avessimo potuto conseguirla, una più ampia cognizione di controversi punti religiosi che hanno portata tanta confusione sopra la terra.
#  PREDICTED: Non mi , ma non mi , ma non mi , e , e , e , e , e , e , e , e , e .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 0 = 0.7560439705848694
# Val WER at end of epoch 0 = 1.0422534942626953
# Val BLEU at end of epoch 0 = 0.0
# Mean training loss at end of epoch 0 = 6.232750327218439
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: I asked the landlord of an inn up the river once, if it did not injure him, sometimes, listening to the tales that the fishermen about there told him; and he said:
#     TARGET: Una volta io chiesi al padrone d’un albergo sul fiume, se non gli facesse male, talvolta, l’ascoltare i racconti che gli toccava sentire dai pescatori, ed egli mi disse:
#  PREDICTED: Io mi il suo posto , non mi , non poteva essere mai mai mai mai mai mai , ma , che non si , e si .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: 'In the following cases: physical defect in husband or wife, five years' absence without news' – and he bent one of his short hairy fingers – 'and in cases of adultery,' he uttered the word with evident pleasure. 'These are subdivided as follows,' and he went on bending down his thick fingers, though the cases and the subdivisions evidently could not be classed together, 'physical defects in husband or in wife, and adultery of husband or of wife.'
#     TARGET: Aspettate! — disse rivolto al procuratore che s’era infilato attraverso la porta, tuttavia si alzò, gli disse alcune parole e sedette di nuovo. — Nei seguenti casi: incapacità fisica dei coniugi, assenza di notizie per cinque anni — disse, piegando il pollice ricoperto di peli — poi adulterio — pronunciò questa parola con evidente soddisfazione. — Le suddivisioni sono le seguenti — egli continuava a piegare le dita grasse, sebbene i casi e le loro suddivisioni non potessero essere elencati insieme: — difetti fisici del marito o della moglie, quindi adulterio del marito o della moglie. — Avendo piegato tutte le dita, le raddrizzò e continuò: — Questo è il punto di vista teorico, ma io suppongo che voi mi abbiate fatto l’onore di rivolgervi a me per conoscere l’applicazione pratica.
#  PREDICTED: — Allora , come è stato , — disse , — — — — — e , sentendo che , con la sua moglie , che , con la sua moglie , e , con la sua moglie , che non è stato un ’ altra cosa , che non è stato stato , e , e , che non si può essere , e , e , e , e , e , e , e , e , e , e , come se non si può essere , e , e , e , e , e , e , e , e , e , e , come se , e , come la sua moglie , e , e , e , e , e , con la sua moglie , e , e , e , come se , come se , che non si la sua moglie , e , e , e , e , e , e , e , e , e , e , e , — disse , con la sua moglie , — disse , con la sua moglie , — disse , con la sua moglie , con la sua moglie , con la sua moglie , con la sua moglie , con la sua moglie , con la sua moglie , con la sua moglie , — disse , con la sua moglie , — disse , — disse disse , con la sua moglie , con la sua moglie , — disse , — disse , — disse , con la sua moglie , — disse , — disse , — disse , — disse , — disse disse disse disse disse disse disse , — disse , — disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse disse ella disse , — disse
# --------------------------------------------------------------------------------
# Val CER at end of epoch 1 = 1.0802083015441895
# Val WER at end of epoch 1 = 2.2437500953674316
# Val BLEU at end of epoch 1 = 0.0
# Mean training loss at end of epoch 1 = 5.535039955463606
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: 'These stupid chignons!
#     TARGET: — Questi stupidi chignons!
#  PREDICTED: — !
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: "Say, 'What do you want, Master Reed?'" was the answer.
#     TARGET: — Dite: Che cosa volete, signor Reed?
#  PREDICTED: — Ebbene , signore , che vi avete detto la signora Reed .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 2 = 0.9047619104385376
# Val WER at end of epoch 2 = 1.3636363744735718
# Val BLEU at end of epoch 2 = 0.0
# Mean training loss at end of epoch 2 = 5.176780917226654
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: 'What are the Shcherbatskys doing?
#     TARGET: — Che fanno gli Šcerbackij?
#  PREDICTED: — Che cosa c ’ è ?
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: That amused Harris.
#     TARGET: Questo divertì Harris.
#  PREDICTED: E Harris si mise a ridere .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 3 = 0.7755101919174194
# Val WER at end of epoch 3 = 1.5
# Val BLEU at end of epoch 3 = 0.0
# Mean training loss at end of epoch 3 = 4.88583473957691
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: I know another way to the house. It does not signify if I knew twenty ways; for he has seen me.
#     TARGET: Non conoscevo un'altra via, ma anche se l'avessi conosciuta, non mi sarebbe giovato a nulla, perché mi aveva veduta.
#  PREDICTED: Io so che la casa non è possibile ; ma non è vero che mi ha fatto ; e ora è ancora .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: "What is the employment you had in view, Mr. Rivers?
#     TARGET: — Qual'era l'occupazione che avevate in vista, signor Rivers?
#  PREDICTED: — Che cosa c ' è stato ?
# --------------------------------------------------------------------------------
# Val CER at end of epoch 4 = 0.700564980506897
# Val WER at end of epoch 4 = 1.0357142686843872
# Val BLEU at end of epoch 4 = 0.0
# Mean training loss at end of epoch 4 = 4.622935485987319
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: CHAPTER XXXI
#     TARGET: XXXI
#  PREDICTED: XI
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: Teach me; I'm not quite up to it."
#     TARGET: Insegnatemelo, Jane, non la so.
#  PREDICTED: , non mi .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 5 = 0.7142857313156128
# Val WER at end of epoch 5 = 0.8333333134651184
# Val BLEU at end of epoch 5 = 0.0
# Mean training loss at end of epoch 5 = 4.3688757427451534
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "There you have a dim and mighty archangel fitly set before you!
#     TARGET: — Avete sottocchio un arcangelo duro e potente.
#  PREDICTED: — Vi siete una ricca e che avete già fatto prima di !
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: "You certainly shall not go till you have told me all," I said.
#     TARGET: — Non permetterò che usciate prima di avermi detto tutto.
#  PREDICTED: — Non vi a dirmi che cosa vi ho detto .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 6 = 0.692307710647583
# Val WER at end of epoch 6 = 1.1111111640930176
# Val BLEU at end of epoch 6 = 0.0
# Mean training loss at end of epoch 6 = 4.1207180153463305
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: Laska walked beside her master, seeking permission to run forward and looking around.
#     TARGET: Laska camminava accanto al padrone, chiedendo di andare avanti e guardandosi in giro.
#  PREDICTED: Laska si accostò al padrone , fece cenno alle scale , e , guardando con passo svelto e guardandola con passo fermo .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: 'In this way – she not only likes you, but says that Kitty is sure to be your wife.'
#     TARGET: — Così: non solo ti vuol bene, ma dice che Kitty sarà certamente tua moglie.
#  PREDICTED: — In questo modo non solo non solo , ma tu dici che è possibile la moglie .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 7 = 0.7204968929290771
# Val WER at end of epoch 7 = 1.1785714626312256
# Val BLEU at end of epoch 7 = 0.0
# Mean training loss at end of epoch 7 = 3.883829331889595
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: I am not able to raise her...'
#     TARGET: Io non posso risollevarla....
#  PREDICTED: Io non sono in piedi in lei .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: There was a smile on his lips, and his eyes sparkled, whether with wine or not, I am not sure; but I think it very probable.
#     TARGET: Forse il vino avevagli procurato quella relativa gaiezza, ma non potrei affermarlo; però nel dopopranzo era più espansivo che la mattina.
#  PREDICTED: V ’ era un sorriso di bocca nel suo naso , e se non fosse il vino , non potrei , ma non credo che sia molto contento .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 8 = 0.7048192620277405
# Val WER at end of epoch 8 = 1.3200000524520874
# Val BLEU at end of epoch 8 = 0.0
# Mean training loss at end of epoch 8 = 3.650621387688155
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: They gathered a basketful of mushrooms; even Lily found one.
#     TARGET: Di funghi se ne raccolse un cestino colmo; perfino Lily trovò un prugnolo.
#  PREDICTED: un ’ dei funghi , ma anche di un altro .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: You're doing it very well, indeed - go on."
#     TARGET: Veramente accompagnate benissimo. Continuate.
#  PREDICTED: Siete bene , .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 9 = 0.7647058963775635
# Val WER at end of epoch 9 = 1.0
# Val BLEU at end of epoch 9 = 0.0
# Mean training loss at end of epoch 9 = 3.4286411878743124
