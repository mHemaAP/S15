# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# %cd /kaggle/working
# !rm -vrf EvS15_dev1
# Out:
# /kaggle/working
# removed 'EvS15_dev1/LightningModel.py'
# removed 'EvS15_dev1/config.py'
# removed 'EvS15_dev1/lightning_logs/version_0/checkpoints/epoch=6-step=33950.ckpt'
# removed directory 'EvS15_dev1/lightning_logs/version_0/checkpoints'
# removed 'EvS15_dev1/lightning_logs/version_0/hparams.yaml'
# removed 'EvS15_dev1/lightning_logs/version_0/events.out.tfevents.1693560099.b11d1bd90e16.28.1'
# removed directory 'EvS15_dev1/lightning_logs/version_0'
# removed directory 'EvS15_dev1/lightning_logs'
# removed 'EvS15_dev1/runs/tmodel/events.out.tfevents.1693560042.b11d1bd90e16.28.0'
# removed directory 'EvS15_dev1/runs/tmodel'
# removed directory 'EvS15_dev1/runs'
# removed 'EvS15_dev1/README.md'
# removed 'EvS15_dev1/.git/logs/HEAD'
# removed 'EvS15_dev1/.git/logs/refs/heads/main'
# removed directory 'EvS15_dev1/.git/logs/refs/heads'
# removed 'EvS15_dev1/.git/logs/refs/remotes/origin/HEAD'
# removed directory 'EvS15_dev1/.git/logs/refs/remotes/origin'
# removed directory 'EvS15_dev1/.git/logs/refs/remotes'
# removed directory 'EvS15_dev1/.git/logs/refs'
# removed directory 'EvS15_dev1/.git/logs'
# removed 'EvS15_dev1/.git/hooks/push-to-checkout.sample'
# removed 'EvS15_dev1/.git/hooks/commit-msg.sample'
# removed 'EvS15_dev1/.git/hooks/update.sample'
# removed 'EvS15_dev1/.git/hooks/applypatch-msg.sample'
# removed 'EvS15_dev1/.git/hooks/pre-merge-commit.sample'
# removed 'EvS15_dev1/.git/hooks/pre-rebase.sample'
# removed 'EvS15_dev1/.git/hooks/pre-push.sample'
# removed 'EvS15_dev1/.git/hooks/fsmonitor-watchman.sample'
# removed 'EvS15_dev1/.git/hooks/pre-applypatch.sample'
# removed 'EvS15_dev1/.git/hooks/post-update.sample'
# removed 'EvS15_dev1/.git/hooks/prepare-commit-msg.sample'
# removed 'EvS15_dev1/.git/hooks/pre-commit.sample'
# removed 'EvS15_dev1/.git/hooks/pre-receive.sample'
# removed directory 'EvS15_dev1/.git/hooks'
# removed 'EvS15_dev1/.git/index'
# removed 'EvS15_dev1/.git/objects/pack/pack-e35c66444af8cb842fb604fc20b9bc8b6d98babc.pack'
# removed 'EvS15_dev1/.git/objects/pack/pack-e35c66444af8cb842fb604fc20b9bc8b6d98babc.idx'
# removed directory 'EvS15_dev1/.git/objects/pack'
# removed directory 'EvS15_dev1/.git/objects'
# removed 'EvS15_dev1/.git/description'
# removed 'EvS15_dev1/.git/info/exclude'
# removed directory 'EvS15_dev1/.git/info'
# removed 'EvS15_dev1/.git/config'
# removed 'EvS15_dev1/.git/HEAD'
# removed 'EvS15_dev1/.git/refs/heads/main'
# removed directory 'EvS15_dev1/.git/refs/heads'
# removed 'EvS15_dev1/.git/refs/remotes/origin/HEAD'
# removed directory 'EvS15_dev1/.git/refs/remotes/origin'
# removed directory 'EvS15_dev1/.git/refs/remotes'
# removed directory 'EvS15_dev1/.git/refs'
# removed 'EvS15_dev1/.git/packed-refs'
# removed directory 'EvS15_dev1/.git'
# removed 'EvS15_dev1/tokenizer_it.json'
# removed 'EvS15_dev1/__pycache__/LightningModel.cpython-310.pyc'
# removed 'EvS15_dev1/__pycache__/config.cpython-310.pyc'
# removed 'EvS15_dev1/__pycache__/dataset.cpython-310.pyc'
# removed 'EvS15_dev1/__pycache__/model.cpython-310.pyc'
# removed directory 'EvS15_dev1/__pycache__'
# removed 'EvS15_dev1/model.py'
# removed 'EvS15_dev1/weights/tmodel_02.pt'
# removed 'EvS15_dev1/weights/tmodel_03.pt'
# removed 'EvS15_dev1/weights/tmodel_05.pt'
# removed 'EvS15_dev1/weights/tmodel_01.pt'
# removed 'EvS15_dev1/weights/tmodel_04.pt'
# removed 'EvS15_dev1/weights/tmodel_06.pt'
# removed 'EvS15_dev1/weights/tmodel_00.pt'
# removed directory 'EvS15_dev1/weights'
# removed 'EvS15_dev1/state.db'
# removed 'EvS15_dev1/dataset.py'
# removed 'EvS15_dev1/tokenizer_en.json'
# removed directory 'EvS15_dev1'

# %%
# %cd /kaggle/working
# !git clone https://github.com/stmhap/EvS15_dev1.git
# %cd EvS15_dev1
# Out:
# /kaggle/working
# Cloning into 'EvS15_dev1'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 10), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 11.90 KiB | 2.97 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /kaggle/working/EvS15_dev1

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 10

# %%
import transformer_litmodule
from pytorch_lightning import LightningModule

myLitmodel = transformer_litmodule.TransformerLitModule(cfg)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# stty: 'standard input': Inappropriate ioctl for device

# %%
from pytorch_lightning import Trainer

trainer = Trainer(
    accelerator = 'gpu',
    max_epochs = cfg['num_epochs'],
    precision= '16-mixed',
)

# %%
# Fit model
trainer.fit(myLitmodel)
# Out:
# Downloading builder script:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/7.98k [00:00<?, ?B/s]
# Downloading and preparing dataset opus_books/en-it (download: 3.14 MiB, generated: 8.58 MiB, post-processed: Unknown size, total: 11.72 MiB) to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf...
# Downloading data:   0%|          | 0.00/3.30M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Dataset opus_books downloaded and prepared to /root/.cache/huggingface/datasets/opus_books/en-it/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf. Subsequent calls will reuse this data.
# Max length of source sentence: 309
# Max length of target sentence: 274
# Sanity Checking: 0it [00:00, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: api feste api api api api carina carina carina carina carina carina carina carina furente furente furente furente furente furente furente furente furente furente carina carina carina carina carina carina carina carina carina carina carina carina carina carina carina carina furente furente furente furente carina carina carina carina furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente carina carina carina furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente carina carina carina carina carina carina furente furente carina carina carina carina furente furente carina carina carina carina carina carina carina carina carina carina carina furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente carina carina carina carina carina carina carina carina carina carina furente furente furente furente furente bowl bowl carina furente furente furente furente furente furente furente carina carina carina carina furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: furente furente furente furente furente furente carina carina furente carina carina carina carina furente furente furente furente furente furente furente furente furente furente furente carina carina carina carina carina carina carina carina carina carina carina carina carina carina carina carina furente furente furente furente carina fermarsi carina fermarsi furente furente furente furente furente furente furente furente furente furente furente furente miglio miglio miglio furente furente furente furente furente miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio similmente miglio similmente similmente furente furente furente furente similmente miglio similmente miglio miglio carina carina similmente miglio similmente miglio miglio miglio miglio carina carina carina carina carina similmente carina carina carina carina carina carina carina carina miglio carina miglio carina miglio carina miglio miglio carina carina carina carina miglio miglio miglio miglio furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente miglio miglio miglio furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente miglio miglio miglio miglio miglio miglio miglio miglio miglio miglio furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente carina carina miglio miglio carina carina carina carina carina furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente carina carina carina carina carina furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente furente
# --------------------------------------------------------------------------------
# Val CER at end of epoch 0 = 31.18343162536621
# Val WER at end of epoch 0 = 25.851852416992188
# Val BLEU at end of epoch 0 = 0.0
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Sì , — disse il signor Rochester .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: E Levin , Levin , Levin , Levin , ma Levin , ma Levin , ma la sua moglie .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 0 = 0.7455621361732483
# Val WER at end of epoch 0 = 1.0370370149612427
# Val BLEU at end of epoch 0 = 0.0
# Mean training loss at end of epoch 0 = 6.2387545067502055
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa ? — disse il signor Rochester .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: E , Anna , Anna , era stato stato così , e che era stato stato stato .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 1 = 0.7278106212615967
# Val WER at end of epoch 1 = 1.0
# Val BLEU at end of epoch 1 = 0.0
# Mean training loss at end of epoch 1 = 5.557178712530234
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa è ? — disse , — e il signor Rochester .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: A questo momento era molto contento di Aleksej Aleksandrovic e si era stata molto contento .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 2 = 0.7692307829856873
# Val WER at end of epoch 2 = 1.0370370149612427
# Val BLEU at end of epoch 2 = 0.0
# Mean training loss at end of epoch 2 = 5.214528107593969
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa ? — domandò il .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: A questo momento , Aleksej Aleksandrovic si era molto bene e lo guardò .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 3 = 0.692307710647583
# Val WER at end of epoch 3 = 0.8888888955116272
# Val BLEU at end of epoch 3 = 0.0
# Mean training loss at end of epoch 3 = 4.933666852626604
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa ? — disse . — È un ' altra cosa .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: Per Aleksej Aleksandrovic era un po ’ di rado , di rado , di lei , e lei ne era contenta .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 4 = 0.6568047404289246
# Val WER at end of epoch 4 = 1.2222222089767456
# Val BLEU at end of epoch 4 = 0.0
# Mean training loss at end of epoch 4 = 4.665558085392431
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa ? — disse , un ' idea di spirito .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: Come Aleksej Aleksandrovic , come era stata innamorata di lei , avrebbe avuto pena .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 5 = 0.6331360936164856
# Val WER at end of epoch 5 = 1.0
# Val BLEU at end of epoch 5 = 0.0
# Mean training loss at end of epoch 5 = 4.412532185525009
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa ? — mi domandò , — che un ' unione .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: Come Aleksej Aleksandrovic era stata una donna estranea , e lei stessa era stata contenta di lei .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 6 = 0.6804733872413635
# Val WER at end of epoch 6 = 1.1111111640930176
# Val BLEU at end of epoch 6 = 0.0
# Mean training loss at end of epoch 6 = 4.167165064615073
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa strana , — mi disse , — che vi chiederà un ' .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: E come Aleksej Aleksandrovic era venuto in lei , non l ’ aveva fatto nulla di male , e l ’ aveva sfidato a lei .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 7 = 0.7455621361732483
# Val WER at end of epoch 7 = 1.4074074029922485
# Val BLEU at end of epoch 7 = 0.0
# Mean training loss at end of epoch 7 = 3.928646828267992
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa vi ha fatto , — rispose , — che un ' opera debba trovare un ' opera .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: Come era stata così poco , l ’ aveva invitato ad Aleksej Aleksandrovic , l ’ aveva ingannata da lei .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 8 = 0.8224852085113525
# Val WER at end of epoch 8 = 1.4444444179534912
# Val BLEU at end of epoch 8 = 0.0
# Mean training loss at end of epoch 8 = 3.691527379763495
# Validation: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
#     SOURCE: "What then, Die?" he replied, maintaining a marble immobility of feature.
#     TARGET: — Ebbene, Diana? — riprese serbando una faccia impassibile. — Ebbene?
#  PREDICTED: — Che cosa vuol bene , — disse , cercando di essere un ' inclinazione per la sua sorgente .
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#     SOURCE: As far as Karenin was concerned she attained her object, and to him she seemed attractive.
#     TARGET: E nei riguardi di Aleksej Aleksandrovic aveva raggiunto lo scopo, ché a lui ella sembrava attraente.
#  PREDICTED: Come poi , Aleksej Aleksandrovic era stata attenta , che le faceva soffrire e che le sembrava naturale .
# --------------------------------------------------------------------------------
# Val CER at end of epoch 9 = 0.7100591659545898
# Val WER at end of epoch 9 = 1.296296238899231
# Val BLEU at end of epoch 9 = 0.0
# Mean training loss at end of epoch 9 = 3.469304443241395
